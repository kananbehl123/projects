# %%
# Zomato data analysis project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/HP/Downloads/Zomato data .csv")

# %%
data
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0]
    return float(value)
data['rate']=data['rate'].apply(handleRate)
print(data.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.info()
# no null values in the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
data.describe()
# Out:
#              rate        votes  approx_cost(for two people)
# count  148.000000   148.000000                   148.000000
# mean     3.633108   264.810811                   418.243243
# std      0.402271   653.676951                   223.085098
# min      2.600000     0.000000                   100.000000
# 25%      3.300000     6.750000                   200.000000
# 50%      3.700000    43.500000                   400.000000
# 75%      3.900000   221.750000                   600.000000
# max      4.600000  4884.000000                   950.000000

# %%
# Type of restaurant
data.head(100)
# Out:
#                           name online_order book_table  rate  votes  \
# 0                        Jalsa          Yes        Yes   4.1    775
# 1               Spice Elephant          Yes         No   4.1    787
# 2              San Churro Cafe          Yes         No   3.8    918
# 3        Addhuri Udupi Bhojana           No         No   3.7     88
# 4                Grand Village           No         No   3.8    166
# ..                         ...          ...        ...   ...    ...
# 95  Vi Ra's Bar and Restaurant           No         No   3.3     62
# 96                      Kaggis           No         No   3.8     64
# 97        Ayda Persian Kitchen           No         No   3.7     39
# 98                Chatar Patar           No         No   3.7     65
# 99                  Polar Bear          Yes         No   3.8     71
#
#     approx_cost(for two people) listed_in(type)
# 0                           800          Buffet
# 1                           800          Buffet
# ...

# %%
order_1 = ["Buffet","Cafes","Dining","other"]
sns.barplot(x=data['listed_in(type)'],y=data['rate'],
            order=order_1,
            hue=data['listed_in(type)'],
            palette='icefire',
            saturation = 10)

plt.show()

# %%
sns.lineplot(x='listed_in(type)',y='votes',data=data,
            size=100,)
plt.show()

# %%
sns.histplot(data['votes'],
            bins=[0,200,400,600,800,1000,1200,1400,1600,1800,2000,2400,3000,5000],
            kde=True)
plt.show()

# %%
sns.scatterplot(x='listed_in(type)',y='votes',data=data)
plt.show()

# %%
sns.stripplot( x='listed_in(type)',y='votes',data=data)
plt.show()

# %%
data = pd.DataFrame({
    'rate': ['A', 'B', 'A', 'B', 'C', 'A', 'B', 'C', 'C', 'C']
})

# Create subplots
f, ax = plt.subplots(1, 2, figsize=(7, 3))

# Calculate value counts and plot pie chart
rate_counts = data['rate'].value_counts()
explode = [0.1] * len(rate_counts)  # Create a list with the same length as the number of slices
rate_counts.plot.pie(explode=explode, autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Rate')

# Plot countplot
sns.countplot(x='rate', data=data, ax=ax[1])

plt.tight_layout()
plt.show()

# %%
data = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6],
    'D': ['X', 'Y', 'Z', 'X', 'Y']  })
numeric_data = data.select_dtypes(include=['number'])

if not numeric_data.empty:
    corr = numeric_data.corr()
    # Plot heatmap
    sns.heatmap(corr, annot=True, cmap='RdYlGn', linewidths=0.2)
    fig = plt.gcf()
    fig.set_size_inches(10, 8)
    plt.show()
else:
    print("No numeric data available to plot.")

# %%
data = pd.DataFrame({
    'votes': ['Yes', 'No', 'Yes', 'No', 'Yes'],
    'online_order': ['Ordered', 'Not Ordered', 'Ordered', 'Ordered', 'Not Ordered']
})
cross_tab = pd.crosstab(data['votes'], data['online_order'], margins=True)

cross_tab.style.background_gradient(cmap='GnBu')
# Out:
# <style type="text/css">
# #T_8725b_row0_col0, #T_8725b_row0_col1, #T_8725b_row0_col2, #T_8725b_row1_col0 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_8725b_row1_col1 {
#   background-color: #7accc4;
#   color: #000000;
# }
# #T_8725b_row1_col2 {
#   background-color: #b4e2ba;
#   color: #000000;
# }
# #T_8725b_row2_col0, #T_8725b_row2_col1, #T_8725b_row2_col2 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8725b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >online_order</th>
#       <th id="T_8725b_level0_col0" class="col_heading level0 col0" >Not Ordered</th>
#       <th id="T_8725b_level0_col1" class="col_heading level0 col1" >Ordered</th>
#       <th id="T_8725b_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >votes</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
sns.catplot(x='online_order', y='votes', data=data, kind='point')
plt.show()
